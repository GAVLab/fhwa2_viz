# %%
#!/usr/bin/env python"""This script used to interpolate msgs from generated dummy inputs, creating msgs at ~100Hz"""import syssys.path.append('/home/gavlab/')from alog_manip.MOOSalog import MOOSalogfrom pprint import pprintlo_file = '/home/gavlab/alog_Files/Long_novatel_plus3.alog'hi_file = '/home/gavlab/alog_Files/Long_novatel_plus3_100Hz.alog'upd_hi = Falseif upd_hi:    desHz = 100    alog = MOOSalog(lo_file, hi_file)    alog.increaseFreq(desHz)    alog.makeChronList()    alog.writeChronListToFile()    alog.closefiles()## Examine outputimport matplotlib.pyplot as pltalog = MOOSalog(hi_file)crs = []crs_t = sorted(alog.srcData['gSRI']['zCourse'])for t in crs_t: # using iteritems may not be in chronological order    crs.append(alog.srcData['gSRI']['zCourse'][t])fig = plt.figure(1)plt.plot(crs_t, crs)plt.title("Course (deg)")plt.show(1)lat = []lat_t = sorted(alog.srcData['gSRI']['zLat'])for t in lat_t:    lat.append(alog.srcData['gSRI']['zLat'][t])fig = plt.figure(2)plt.plot(lat_t, lat)plt.title("Latitude (dec. deg.)")plt.show(2)lon = []lon_t = sorted(alog.srcData['gSRI']['zLong'])for t in lon_t:    lon.append(alog.srcData['gSRI']['zLong'][t])fig = plt.figure(3)plt.plot(lon_t, lon)plt.title("Longitude (dec. deg.)")plt.show()latstd = []latstd_t = sorted(alog.srcData['gSRI']['zLatStdDev'])for t in latstd_t:    latstd.append(alog.srcData['gSRI']['zLatStdDev'][t])fig = plt.figure()plt.plot(latstd_t, latstd)plt.title("Lat Std Dev (m)")plt.show()lonstd = []lonstd_t = sorted(alog.srcData['gSRI']['zLongStdDev'])for t in lonstd_t:    lonstd.append(alog.srcData['gSRI']['zLongStdDev'][t])fig = plt.figure()plt.plot(lonstd_t, lonstd)plt.title("Long Std Dev")plt.show()
